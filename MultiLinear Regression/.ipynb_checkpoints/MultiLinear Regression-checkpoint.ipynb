# %% [markdown]
# # Data and Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns

# %%
# Load the data
df = pd.read_csv('salaries.csv')
df.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %% [markdown]
# # Analysing the data

# %%
# Summary Statistics
df.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %%
# plotting continuous Independant Variable against dependant variable
sns.set(font_scale=1.75)
sns.pairplot(data = df, y_vars=['salary'], x_vars=['yrs.service', 'yrs.since.phd'], height = 7)

# %%
# Correlation Matrix
sns.heatmap(df.corr(), annot=True, fmt='.2g', center=0, cmap="coolwarm", linewidths=1, linecolor='black')
# Out:
# <AxesSubplot:>

# %%
# Categorical Variables
df['rank'].value_counts()
df.select_dtypes(include='object').value_counts()
# Out:
# rank       discipline  sex
# Prof       B           Male      125
#            A           Male      123
# AsstProf   B           Male       38
# AssocProf  B           Male       32
#            A           Male       22
# AsstProf   A           Male       18
# Prof       B           Female     10
#            A           Female      8
# AssocProf  B           Female      6
# AsstProf   A           Female      6
#            B           Female      5
# AssocProf  A           Female      4
# dtype: int64

# %%
# For loop categorical variables
categorical = list(df.select_dtypes(include='object'))
for cat in categorical:
    print(df[cat].value_counts())
# Out:
# Prof         266
# AsstProf      67
# AssocProf     64
# Name: rank, dtype: int64
# B    216
# A    181
# Name: discipline, dtype: int64
# Male      358
# Female     39
# Name: sex, dtype: int64

# %%
# Data set reminder
df.head(1)
# Out:
#    rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0  Prof          B             19           18  Male  139750

# %%
# Transform objects into dummies
df = pd.get_dummies(data = df, drop_first=True)
df.head(2)
# Out:
#    yrs.since.phd  yrs.service  salary  rank_AsstProf  rank_Prof  discipline_B  \
# 0             19           18  139750              0          1             1
# 1             20           16  173200              0          1             1
#
#    sex_Male
# 0         1
# 1         1

# %% [markdown]
# # Multilinear Regression preparation

# %%
# isolate X and y
y = df.salary / 1000
X = df.drop(columns=['salary', 'yrs.service'])
X.head()
# Out:
#    yrs.since.phd  rank_AsstProf  rank_Prof  discipline_B  sex_Male
# 0             19              0          1             1         1
# 1             20              0          1             1         1
# 2              4              1          0             1         1
# 3             45              0          1             1         1
# 4             40              0          1             1         1

# %%
# Add a constant
X = sm.add_constant(X)
X
# Out:
#      const  yrs.since.phd  rank_AsstProf  rank_Prof  discipline_B  sex_Male
# 0      1.0             19              0          1             1         1
# 1      1.0             20              0          1             1         1
# 2      1.0              4              1          0             1         1
# 3      1.0             45              0          1             1         1
# 4      1.0             40              0          1             1         1
# ..     ...            ...            ...        ...           ...       ...
# 392    1.0             33              0          1             0         1
# 393    1.0             31              0          1             0         1
# 394    1.0             42              0          1             0         1
# 395    1.0             25              0          1             0         1
# 396    1.0              8              1          0             0         1
#
# [397 rows x 6 columns]

# %%
# Training and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 1502)

X_train.head()
# Out:
#      const  yrs.since.phd  rank_AsstProf  rank_Prof  discipline_B  sex_Male
# 105    1.0             31              0          1             0         1
# 287    1.0              2              1          0             0         1
# 326    1.0             23              0          1             1         1
# 15     1.0             12              0          1             1         1
# 354    1.0              8              1          0             1         1

# %% [markdown]
# # Multilinear Regression

# %%
# Multilinear Regression
model1 = sm.OLS(y_train, X_train).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 salary   R-squared:                       0.475
# Model:                            OLS   Adj. R-squared:                  0.466
# Method:                 Least Squares   F-statistic:                     56.20
# Date:                Mon, 28 Aug 2023   Prob (F-statistic):           1.65e-41
# Time:                        11:55:22   Log-Likelihood:                -1424.2
# No. Observations:                 317   AIC:                             2860.
# Df Residuals:                     311   BIC:                             2883.
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            79.6855      5.408     14.735      0.000      69.045      90.326
# yrs.since.phd    -0.0283      0.134     -0.211      0.833      -0.293       0.236
# rank_AsstProf   -13.1259      4.629     -2.836      0.005     -22.233      -4.019
# rank_Prof        34.7651      3.930      8.846      0.000      27.032      42.498
# discipline_B     15.6270      2.560      6.105      0.000      10.591      20.663
# sex_Male          5.3569      4.277      1.252      0.211      -3.059      13.773
# ==============================================================================
# Omnibus:                       39.418   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.815
# Skew:                           0.715   Prob(JB):                     6.92e-16
# Kurtosis:                       4.800   Cond. No.                         146.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Accuracy Assesment

# %%
# Predict 
preds = model1.predict(X_test)
preds[:4]
# Out:
# 364    118.590061
# 30     134.868270
# 378    118.731635
# 188     99.876615
# dtype: float64

# %%
# Accuracy Assemsment
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
print("MAE:",  round(mean_absolute_error(y_test, preds),1))
print("RMSE:", round(np.sqrt(mean_squared_error(y_test, preds)),1))
# Out:
# MAE: 18.2
# RMSE: 25.8

# %% [markdown]
# # Challenge
# ### Using Multilinear Regresion to Study a Store Sales' drivers
#  * Task 1: Pick Variables for model
#  * Task 2: Analyze Data i.e Summary Statistics
#  * Task 3: Correlation Matrix
#  * Task 4: Create a Training and Test set
#  * Task 5: Use Multilinear Regression
#  * Task 6: Asses Accuracy

# %%
# Import data
data = pd.read_csv('Clothing.csv')
data.head()
# Out:
#     tsales      sales  margin  nown   nfull   npart    naux  hoursw   hourspw  \
# 0   750000   4411.765    41.0   1.0  1.0000  1.0000  1.5357      76  16.75596
# 1  1926395   4280.878    39.0   2.0  2.0000  3.0000  1.5357     192  22.49376
# 2  1250000   4166.667    40.0   1.0  2.0000  2.2222  1.4091     114  17.19120
# 3   694227   2670.104    40.0   1.0  1.0000  1.2833  1.3673     100  21.50260
# 4   750000  15000.000    44.0   2.0  1.9556  1.2833  1.3673     104  15.74279
#
#         inv1      inv2  ssize  start
# 0   17166.67  27177.04    170   41.0
# 1   17166.67  27177.04    450   39.0
# 2  292857.20  71570.55    300   40.0
# 3   22207.04  15000.00    260   40.0
# 4   22207.04  10000.00     50   44.0

# %%
data.tsales = data.tsales/1000
data.sales = data.sales/1000
data.inv1 = data.inv1/1000
data.inv2 = data.inv2/1000
data.describe()
# Out:
#             tsales       sales      margin        nown       nfull  \
# count   400.000000  400.000000  400.000000  400.000000  400.000000
# mean    833.584213    6.334751   38.774230    1.283796    2.069384
# std     583.463838    3.739344    5.218184    0.639773    1.015598
# min      50.000000    0.300000   16.000000    1.000000    1.000000
# 25%     495.340000    3.904200   37.000000    1.000000    1.923100
# 50%     694.227000    5.278935   39.000000    1.000000    1.955600
# 75%     976.817000    7.739899   41.000000    1.295225    2.066400
# max    5000.000000   27.000000   66.000000   10.000000    8.000000
#
#             npart        naux      hoursw     hourspw         inv1  \
# count  400.000000  400.000000  400.000000  400.000000   400.000000
# mean     1.565539    1.389747  121.137500   18.955044    58.257255
# std      0.705999    0.394514   64.435343    7.343363   107.558771
# min      1.000000    1.000000   32.000000    5.707966     1.000000
# 25%      1.283300    1.333300   80.000000   13.541198    20.000000
# 50%      1.283300    1.367300  104.000000   17.744585    22.207040
# 75%      2.000000    1.367300  145.250000   24.302982    62.269230
# max      9.000000    4.000000  582.000000   43.326020  1500.000000
#
#              inv2        ssize       start
# count  400.000000   400.000000  400.000000
# mean    27.829217   151.050000   42.808462
# std     41.501943   112.498254   13.296070
# min      0.350000    16.000000   16.000000
# 25%     10.000000    80.000000   37.000000
# 50%     22.859850   120.000000   40.000000
# 75%     22.859850   190.000000   42.000000
# max    400.000000  1214.000000   90.000000

# %%
sns.set(font_scale=1.5)
sns.pairplot(data= data, y_vars=['tsales'], x_vars=['inv1', 'inv2', 'nfull', 'hoursw', 'ssize'], height=5)

# %%
# Correlation Matrix
sns.set(rc = {'figure.figsize':(10, 10)}, font_scale=1)
sns.heatmap(data=data.corr(), annot = True, fmt='.2g', center=0, cmap='coolwarm',linewidths=1, linecolor='black' )
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Dependant variables to be used: nfull, hourspw, margin, inv2, ssize

# %% [markdown]
# # Multilinear Preparation

# %%
y = data.tsales
X = data.drop(columns=['tsales', 'sales', 'nown', 'npart', 'naux', 'hoursw', 'inv1', 'start'])
X = sm.add_constant(X)
X.head(2)
# Out:
#    const  margin  nfull   hourspw      inv2  ssize
# 0    1.0    41.0    1.0  16.75596  27.17704    170
# 1    1.0    39.0    2.0  22.49376  27.17704    450

# %%
# Split
X_train, X_test, y_train, y_test = test_t
# Out:
#      const  margin   nfull   hourspw       inv2  ssize
# 0      1.0    41.0  1.0000  16.75596   27.17704    170
# 1      1.0    39.0  2.0000  22.49376   27.17704    450
# 2      1.0    40.0  2.0000  17.19120   71.57055    300
# 3      1.0    40.0  1.0000  21.50260   15.00000    260
# 4      1.0    44.0  1.9556  15.74279   10.00000     50
# ..     ...     ...     ...       ...        ...    ...
# 395    1.0    37.0  1.9231  19.05181   80.00000    100
# 396    1.0    40.0  8.0000   6.31579  126.80000    300
# 397    1.0    40.0  1.0000  17.93267   27.17704    100
# 398    1.0    36.0  2.0000  25.77867   27.17704    375
# 399    1.0    39.0  1.9556  14.12510   22.85985     70
#
# [400 rows x 6 columns]
